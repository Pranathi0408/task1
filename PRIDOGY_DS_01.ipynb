# %% [markdown]
# # TASK 1

# %%
#importing required libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import warnings
warnings.filterwarnings("ignore")
import csv

# %%
pwd
# Out:
# 'C:\\Users\\suman'

# %%
#importing the dataset
data = pd.read_csv(r"C:\Users\suman\OneDrive\Desktop\Metadata_Country_API_SP.POP.TOTL_DS2_en_csv_v2_340879.csv")

# %%
data
# Out:
#     Country Code                      Region          IncomeGroup  \
# 0            ABW   Latin America & Caribbean          High income
# 1            AFE                         NaN                  NaN
# 2            AFG                  South Asia           Low income
# 3            AFW                         NaN                  NaN
# 4            AGO          Sub-Saharan Africa  Lower middle income
# ..           ...                         ...                  ...
# 260          XKX       Europe & Central Asia  Upper middle income
# 261          YEM  Middle East & North Africa           Low income
# 262          ZAF          Sub-Saharan Africa  Upper middle income
# 263          ZMB          Sub-Saharan Africa  Lower middle income
# 264          ZWE          Sub-Saharan Africa  Lower middle income
#
#                                           SpecialNotes  \
# 0                                                  NaN
# 1    26 countries, stretching from the Red Sea in t...
# ...

# %%
#no of rows and columns in dataset
data.shape
# Out:
# (265, 6)

# %%
#starting rows in dataset
data.head()
# Out:
#   Country Code                     Region          IncomeGroup  \
# 0          ABW  Latin America & Caribbean          High income
# 1          AFE                        NaN                  NaN
# 2          AFG                 South Asia           Low income
# 3          AFW                        NaN                  NaN
# 4          AGO         Sub-Saharan Africa  Lower middle income
#
#                                         SpecialNotes  \
# 0                                                NaN
# 1  26 countries, stretching from the Red Sea in t...
# 2  The reporting period for national accounts dat...
# 3  22 countries, stretching from the westernmost ...
# 4  The World Bank systematically assesses the app...
#
#                      TableName  Unnamed: 5
# 0                        Aruba         NaN
# 1  Africa Eastern and Southern         NaN
# 2                  Afghanistan         NaN
# 3   Africa Western and Central         NaN
# 4                       Angola         NaN

# %%
#last rows in dataset
data.tail()
# Out:
#     Country Code                      Region          IncomeGroup  \
# 260          XKX       Europe & Central Asia  Upper middle income
# 261          YEM  Middle East & North Africa           Low income
# 262          ZAF          Sub-Saharan Africa  Upper middle income
# 263          ZMB          Sub-Saharan Africa  Lower middle income
# 264          ZWE          Sub-Saharan Africa  Lower middle income
#
#                                           SpecialNotes     TableName  \
# 260                                                NaN        Kosovo
# 261  The World Bank systematically assesses the app...   Yemen, Rep.
# 262  Fiscal year end: March 31; reporting period fo...  South Africa
# 263  National accounts data were rebased to reflect...        Zambia
# 264  National Accounts data are reported in Zimbabw...      Zimbabwe
#
#      Unnamed: 5
# 260         NaN
# 261         NaN
# 262         NaN
# 263         NaN
# 264         NaN

# %%
data.columns
# Out:
# Index(['Country Code', 'Region', 'IncomeGroup', 'SpecialNotes', 'TableName',
#        'Unnamed: 5'],
#       dtype='object')

# %%
data.dtypes
# Out:
# Country Code     object
# Region           object
# IncomeGroup      object
# SpecialNotes     object
# TableName        object
# Unnamed: 5      float64
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 265 entries, 0 to 264
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country Code  265 non-null    object
#  1   Region        217 non-null    object
#  2   IncomeGroup   216 non-null    object
#  3   SpecialNotes  126 non-null    object
#  4   TableName     265 non-null    object
#  5   Unnamed: 5    0 non-null      float64
# dtypes: float64(1), object(5)
# memory usage: 12.6+ KB

# %%
#getting details
data.describe()
# Out:
#        Unnamed: 5
# count         0.0
# mean          NaN
# std           NaN
# min           NaN
# 25%           NaN
# 50%           NaN
# 75%           NaN
# max           NaN

# %%
data.duplicated().sum()
# Out:
# 0

# %%
#isna()//method to check any null values are there or missing values in the data set
#sum() //calculate the count of null values in data
data.isna().sum().any()
# Out:
# True

# %%
data.isna().sum().any()
# Out:
# True

# %%
#selection of required columns
df1=data[["Country Code","Region","IncomeGroup","TableName"]]
df1.head(10)
# Out:
#   Country Code                      Region          IncomeGroup  \
# 0          ABW   Latin America & Caribbean          High income
# 1          AFE                         NaN                  NaN
# 2          AFG                  South Asia           Low income
# 3          AFW                         NaN                  NaN
# 4          AGO          Sub-Saharan Africa  Lower middle income
# 5          ALB       Europe & Central Asia  Upper middle income
# 6          AND       Europe & Central Asia          High income
# 7          ARB                         NaN                  NaN
# 8          ARE  Middle East & North Africa          High income
# 9          ARG   Latin America & Caribbean  Upper middle income
#
#                      TableName
# 0                        Aruba
# 1  Africa Eastern and Southern
# 2                  Afghanistan
# 3   Africa Western and Central
# 4                       Angola
# 5                      Albania
# 6                      Andorra
# ...

# %%
#changing colunm name table name by country name
df1=df1.copy()
df1.dropna(subset=['Region'], inplace=True)
df1.rename(columns={'TableName': 'CountryName'}, inplace=True)
df1.head(10)
# Out:
#    Country Code                      Region          IncomeGroup  \
# 0           ABW   Latin America & Caribbean          High income
# 2           AFG                  South Asia           Low income
# 4           AGO          Sub-Saharan Africa  Lower middle income
# 5           ALB       Europe & Central Asia  Upper middle income
# 6           AND       Europe & Central Asia          High income
# 8           ARE  Middle East & North Africa          High income
# 9           ARG   Latin America & Caribbean  Upper middle income
# 10          ARM       Europe & Central Asia  Upper middle income
# 11          ASM         East Asia & Pacific          High income
# 12          ATG   Latin America & Caribbean          High income
#
#              CountryName
# 0                  Aruba
# 2            Afghanistan
# 4                 Angola
# 5                Albania
# 6                Andorra
# 8   United Arab Emirates
# 9              Argentina
# 10               Armenia
# ...

# %%
data['Country Code'].unique()
# Out:
# array(['ABW', 'AFE', 'AFG', 'AFW', 'AGO', 'ALB', 'AND', 'ARB', 'ARE',
#        'ARG', 'ARM', 'ASM', 'ATG', 'AUS', 'AUT', 'AZE', 'BDI', 'BEL',
#        'BEN', 'BFA', 'BGD', 'BGR', 'BHR', 'BHS', 'BIH', 'BLR', 'BLZ',
#        'BMU', 'BOL', 'BRA', 'BRB', 'BRN', 'BTN', 'BWA', 'CAF', 'CAN',
#        'CEB', 'CHE', 'CHI', 'CHL', 'CHN', 'CIV', 'CMR', 'COD', 'COG',
#        'COL', 'COM', 'CPV', 'CRI', 'CSS', 'CUB', 'CUW', 'CYM', 'CYP',
#        'CZE', 'DEU', 'DJI', 'DMA', 'DNK', 'DOM', 'DZA', 'EAP', 'EAR',
#        'EAS', 'ECA', 'ECS', 'ECU', 'EGY', 'EMU', 'ERI', 'ESP', 'EST',
#        'ETH', 'EUU', 'FCS', 'FIN', 'FJI', 'FRA', 'FRO', 'FSM', 'GAB',
#        'GBR', 'GEO', 'GHA', 'GIB', 'GIN', 'GMB', 'GNB', 'GNQ', 'GRC',
#        'GRD', 'GRL', 'GTM', 'GUM', 'GUY', 'HIC', 'HKG', 'HND', 'HPC',
#        'HRV', 'HTI', 'HUN', 'IBD', 'IBT', 'IDA', 'IDB', 'IDN', 'IDX',
#        'IMN', 'IND', 'IRL', 'IRN', 'IRQ', 'ISL', 'ISR', 'ITA', 'JAM',
# ...

# %%
data['Region'].unique()
# Out:
# array(['Latin America & Caribbean', 'South Asia', 'Sub-Saharan Africa',
#        'Europe & Central Asia', 'Middle East & North Africa',
#        'East Asia & Pacific', 'North America'], dtype=object)

# %%
#plotting bar chart for distribution of region
Region_counts = data['Region'].value_counts() #calculate the all the indivials values of data set
print(f'\ncounts of countries by Region  :\n\n{Region_counts}\n')
x=range(len(Region_counts.index))

#coustimizing the plot
plt.figure(figsize=(10, 6))
plt.bar(Region_counts.index,Region_counts.values,color='#CD1FD2')
plt.xlabel('Region groups', fontsize=15)
plt.ylabel('Region Counts', fontsize=15)
plt.title('Categorical Distribution of Region',fontsize=18)

plt.xticks(x,Region_counts.index,rotation=50,color='#1FBCD2', fontsize=16)
plt.legend(title='Region',fontsize=15)
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# counts of countries by Region  :
#
# Region
# Europe & Central Asia         67
# Sub-Saharan Africa            56
# Latin America & Caribbean     49
# East Asia & Pacific           46
# Middle East & North Africa    31
# South Asia                    12
# North America                  4
# Name: count, dtype: int64

# %%
#plotting bar chart for distribution of income
IncomeGroup_counts = data['IncomeGroup'].value_counts() #calculate the all the indivials values of data set
print(f'\ncounts of countries by IncomeGroup  :\n\n{IncomeGroup_counts}\n')
x=range(len(Region_counts.index))

#coustimizing the plot
plt.figure(figsize=(10, 6))
plt.bar(IncomeGroup_counts.index,IncomeGroup_counts.values,color='#D21F1F')
plt.xlabel('Income Groups', fontsize=15)
plt.ylabel('Counts', fontsize=15)
plt.title('Categorical Distribution of IncomeGroups',fontsize=18)
plt.legend(title='IncomeGroups',fontsize=15)
plt.show()#to show the graph
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# counts of countries by IncomeGroup  :
#
# IncomeGroup
# High income            94
# Upper middle income    69
# Lower middle income    68
# Low income             34
# Name: count, dtype: int64

# %%
#Creating a 2D catogorical distribution with Region and IncomeGroup
categorical_distribution = pd.crosstab(data['Region'],data['IncomeGroup'])
#plotting a bar plot using pandas plot() funtion
categorical_distribution.plot(kind='bar',stacked = True,figsize=(10, 8), fontsize=12)
#coustimizing the plot (optional)
plt.xlabel('Region', fontsize=15)
plt.ylabel('Count', fontsize=15)
plt.title('2-D Categorical Distribution: Region vs IncomeGroups',fontsize=15)
plt.legend(title='IncomeGroups',fontsize=15)
plt.tight_layout
plt.show()#to show the graph
